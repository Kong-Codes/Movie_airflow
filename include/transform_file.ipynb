# %%
import pandas as pd

# %%
df = pd.read_csv('movie.csv')

# %%
df
# Out:
#                               Title  Year      Rated  Runtime  \
# 0                            Meteor  1979         PG  108 min
# 1                          Ruthless  1948     Passed  104 min
# 2   Godzilla x Kong: The New Empire  2024      PG-13      NaN
# 3                       Death Alley  2021        NaN   94 min
# 4                       The Marvels  2023      PG-13  105 min
# 5                    Red Right Hand  2022  Not Rated   74 min
# 6                              Wish  2023         PG   95 min
# 7         SKAL - FIGHT FOR SURVIVAL  2023        NaN   77 min
# 8                          Spaceman  2016          R   90 min
# 9                     The Beekeeper  2024          R  105 min
# 10                    Kung Fu Panda  2008         PG   92 min
# 11     Aquaman and the Lost Kingdom  2023      PG-13  124 min
# 12                      The Kindred  1987          R   93 min
# 13                  Kung Fu Panda 2  2011         PG   90 min
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       16 non-null     object
#  1   Year        16 non-null     int64
#  2   Rated       12 non-null     object
#  3   Runtime     15 non-null     object
#  4   Genre       16 non-null     object
#  5   Director    16 non-null     object
#  6   Actors      15 non-null     object
#  7   Plot        16 non-null     object
#  8   Language    15 non-null     object
#  9   Country     16 non-null     object
#  10  Poster      16 non-null     object
#  11  imdbRating  13 non-null     float64
#  12  Type        16 non-null     object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.8+ KB

# %%
df['Rated'] = df['Rated'].fillna('Not Rated')

# %%
df[['Runtime', 'del']] = df['Runtime'].str.split(' ', expand=True)

# %%
df
# Out:
#                               Title  Year      Rated Runtime  \
# 0                            Meteor  1979         PG     108
# 1                          Ruthless  1948     Passed     104
# 2   Godzilla x Kong: The New Empire  2024      PG-13     NaN
# 3                       Death Alley  2021  Not Rated      94
# 4                       The Marvels  2023      PG-13     105
# 5                    Red Right Hand  2022  Not Rated      74
# 6                              Wish  2023         PG      95
# 7         SKAL - FIGHT FOR SURVIVAL  2023  Not Rated      77
# 8                          Spaceman  2016          R      90
# 9                     The Beekeeper  2024          R     105
# 10                    Kung Fu Panda  2008         PG      92
# 11     Aquaman and the Lost Kingdom  2023      PG-13     124
# 12                      The Kindred  1987          R      93
# 13                  Kung Fu Panda 2  2011         PG      90
# ...

# %%
df['Runtime'] = df['Runtime'].fillna(0)

# %%
df['imdbRating'] = df['imdbRating'].fillna(0)

# %%
df['Language'] = df['Language'].fillna('Unspecified')

# %%
df['Actors'] = df['Actors'].fillna('Unspecified')

# %%
df.drop(columns='del', inplace=True)
